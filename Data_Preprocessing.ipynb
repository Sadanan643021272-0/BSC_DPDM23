# %% [markdown]
# <a href="https://colab.research.google.com/github/Sadanan643021272-0/BSC_DPDM23/blob/main/Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ข้อมูลบางส่วนมีค่าตัวแปรบางตัวที่ไม่ทราบค่า (Missing Data)

# %%
import pandas as pd

# %%
#mounting colab with google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
shopping_data = pd.read_csv('/content/drive/MyDrive/BSC_DPDM23/customer_shopping_data - customer_shopping_data.csv')
shopping_data.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon

# %%
shopping_data.isnull()
# Out:
#        invoice_no  customer_id  gender    age  category  quantity  price  \
# 0           False        False   False  False     False     False  False
# 1           False        False   False  False     False     False  False
# 2           False        False   False  False     False     False  False
# 3           False        False   False  False     False     False  False
# 4           False        False   False  False     False     False  False
# ...           ...          ...     ...    ...       ...       ...    ...
# 99452       False        False   False  False     False     False  False
# 99453       False        False   False  False     False     False  False
# 99454       False        False   False  False     False     False  False
# 99455       False        False   False  False     False     False  False
# 99456       False        False   False  False     False     False  False
#
#        payment_method  invoice_date  shopping_mall
# 0               False         False          False
# 1               False         False          False
# 2               False         False          False
# 3               False         False          False
# 4               False         False          False
# ...               ...           ...            ...
# 99452           False         False          False
# 99453           False         False          False
# 99454           False         False          False
# 99455           False         False          False
# 99456           False         False          False
#
# [99457 rows x 10 columns]

# %%
shopping_data.isnull().any()
# Out:
# invoice_no        False
# customer_id       False
# gender            False
# age               False
# category          False
# quantity          False
# price             False
# payment_method    False
# invoice_date      False
# shopping_mall     False
# dtype: bool

# %% [markdown]
# .isnull## Example

# %% [markdown]
# ##เราจะลบ Price ของ Records ที่เป็น Clothing, Cash, Metrocity ออก เพื่อจำลองง Missing data

# %%
shopping_data[(shopping_data['category']=='Clothing')
&(shopping_data['payment_method']=='Cash')
&(shopping_data['shopping_mall']=='Metrocity')].describe()
# Out:
#                age     quantity        price
# count  2284.000000  2284.000000  2284.000000
# mean     43.657618     2.982049   894.853275
# std      14.974270     1.408979   422.806539
# min      18.000000     1.000000   300.080000
# 25%      30.750000     2.000000   600.160000
# 50%      44.000000     3.000000   900.240000
# 75%      57.000000     4.000000  1200.320000
# max      69.000000     5.000000  1500.400000

# %%
shopping_new = shopping_data[shopping_data['category']=='Clothing']
shopping_new2=shopping_new[shopping_new['payment_method']=='Cash']
shopping_new3 = shopping_new2[shopping_new2['shopping_mall']=='Metrocity']
shopping_new3
# Out:
#       invoice_no customer_id  gender  age  category  quantity    price  \
# 2        I127801     C266599    Male   20  Clothing         1   300.08
# 382      I591015     C286181  Female   69  Clothing         1   300.08
# 446      I423124     C109593  Female   66  Clothing         1   300.08
# 531      I223795     C280596    Male   40  Clothing         3   900.24
# 647      I891465     C175833  Female   19  Clothing         1   300.08
# ...          ...         ...     ...  ...       ...       ...      ...
# 98987    I693615     C323954  Female   33  Clothing         2   600.16
# 99153    I922072     C336171    Male   47  Clothing         4  1200.32
# 99178    I135939     C211085    Male   40  Clothing         3   900.24
# 99339    I287566     C216529  Female   48  Clothing         1   300.08
# 99390    I283542     C780439    Male   35  Clothing         1   300.08
#
#       payment_method invoice_date shopping_mall
# 2               Cash    9/11/2021     Metrocity
# 382             Cash    12/9/2021     Metrocity
# 446             Cash     7/1/2023     Metrocity
# 531             Cash   26/12/2022     Metrocity
# 647             Cash   21/07/2022     Metrocity
# ...              ...          ...           ...
# 98987           Cash     7/2/2021     Metrocity
# 99153           Cash   22/01/2021     Metrocity
# 99178           Cash    1/11/2022     Metrocity
# 99339           Cash   25/02/2023     Metrocity
# 99390           Cash   25/04/2021     Metrocity
#
# [2284 rows x 10 columns]

# %%
import numpy as np

# %%
willbemissing = shopping_data[(shopping_data['category']=='Clothing')&
                      (shopping_data['payment_method']=='Cash')&
                      (shopping_data['shopping_mall']=='Metrocity')]

# %%
willbemissing
# Out:
#       invoice_no customer_id  gender  age  category  quantity    price  \
# 2        I127801     C266599    Male   20  Clothing         1   300.08
# 382      I591015     C286181  Female   69  Clothing         1   300.08
# 446      I423124     C109593  Female   66  Clothing         1   300.08
# 531      I223795     C280596    Male   40  Clothing         3   900.24
# 647      I891465     C175833  Female   19  Clothing         1   300.08
# ...          ...         ...     ...  ...       ...       ...      ...
# 98987    I693615     C323954  Female   33  Clothing         2   600.16
# 99153    I922072     C336171    Male   47  Clothing         4  1200.32
# 99178    I135939     C211085    Male   40  Clothing         3   900.24
# 99339    I287566     C216529  Female   48  Clothing         1   300.08
# 99390    I283542     C780439    Male   35  Clothing         1   300.08
#
#       payment_method invoice_date shopping_mall
# 2               Cash    9/11/2021     Metrocity
# 382             Cash    12/9/2021     Metrocity
# 446             Cash     7/1/2023     Metrocity
# 531             Cash   26/12/2022     Metrocity
# 647             Cash   21/07/2022     Metrocity
# ...              ...          ...           ...
# 98987           Cash     7/2/2021     Metrocity
# 99153           Cash   22/01/2021     Metrocity
# 99178           Cash    1/11/2022     Metrocity
# 99339           Cash   25/02/2023     Metrocity
# 99390           Cash   25/04/2021     Metrocity
#
# [2284 rows x 10 columns]

# %% [markdown]
# ##แยก data ส่วนที่ไม่ missing ออกมา

# %%
nomissing=shopping_data[(shopping_data['category']!='Clothing')|
              (shopping_data['payment_method']!='Cash') |
              (shopping_data['shopping_mall']!='Metrocity') ]

# %%
new_shopping_data=pd.concat([willbemissing,nomissing])
new_shopping_data
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 382      I591015     C286181  Female   69         Clothing         1   300.08
# 446      I423124     C109593  Female   66         Clothing         1   300.08
# 531      I223795     C280596    Male   40         Clothing         3   900.24
# 647      I891465     C175833  Female   19         Clothing         1   300.08
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 2               Cash    9/11/2021         Metrocity
# 382             Cash    12/9/2021         Metrocity
# 446             Cash     7/1/2023         Metrocity
# 531             Cash   26/12/2022         Metrocity
# 647             Cash   21/07/2022         Metrocity
# ...              ...          ...               ...
# 99452    Credit Card   21/09/2022            Kanyon
# 99453           Cash   22/09/2021    Forum Istanbul
# 99454     Debit Card   28/03/2021         Metrocity
# 99455           Cash   16/03/2021      Istinye Park
# 99456    Credit Card   15/10/2022  Mall of Istanbul
#
# [99457 rows x 10 columns]

# %%
new_shopping_data.isnull().any()
# Out:
# invoice_no        False
# customer_id       False
# gender            False
# age               False
# category          False
# quantity          False
# price             False
# payment_method    False
# invoice_date      False
# shopping_mall     False
# dtype: bool

# %% [markdown]
# ##แก้ค่าAge

# %% [markdown]
# ##QUIZ -
# -data หายไปกี่% -mean data หลังจากการแก้missing เป็นเท่าไหร่

# %%
new_shopping_data_drop=new_shopping_data.dropna()

# %%
100*((len(new_shopping_data)-len(new_shopping_data_drop))/len(new_shopping_data))
# Out:
# 0.0

# %% [markdown]
# ###mean data หลังรวมจากแก้missing

# %%
new_shopping_data = pd.concat([willbemissing,nonmissing])
new_shopping_data.shape
# Out:
# (67254, 10)

# %% [markdown]
# ## Fix

# %% [markdown]
# ###IGNORE (ลบออกไป)

# %% [markdown]
# # ข้อมูลมีความซ้ำซ้อน (Duplicate Data)

# %% [markdown]
# ##quiz 4ตัว เติมค่าเฉลี่ยของกลุ่ม
# -mean หลังเติมด้วยค่าเฉลี่ย Clothing
# -mean หลังจากเติมค่าเฉลี่ย Cash
# -mean หลังเติมด้วยค่าเฉลี่ย Megacity
# -mean หลังเติมด้วยค่าเฉลี่ย Cash +Megacity

# %% [markdown]
# 4

# %% [markdown]
# ## Example

# %% [markdown]
# ## Fix

# %% [markdown]
# # ข้อมูลบางตัวในชุดข้อมูลมีลักษณะผิดปกติหรือแตกต่างจากข้อมูลส่วนใหญ่ (Outlier)

# %% [markdown]
# ## Example

# %% [markdown]
# ## Fix

# %% [markdown]
# # ค่าตัวแปรบางตัวที่ไม่ถูกต้อง (Erroneous Data)

# %%
shopping_data.describe
# Out:
# <bound method NDFrame.describe of       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 0        Credit Card     5/8/2022            Kanyon
# 1         Debit Card   12/12/2021    Forum Istanbul
# 2               Cash    9/11/2021         Metrocity
# 3        Credit Card   16/05/2021      Metropol AVM
# 4               Cash   24/10/2021            Kanyon
# ...              ...          ...               ...
# 99452    Credit Card   21/09/2022            Kanyon
# 99453           Cash   22/09/2021    Forum Istanbul
# 99454     Debit Card   28/03/2021         Metrocity
# 99455           Cash   16/03/2021      Istinye Park
# 99456    Credit Card   15/10/2022  Mall of Istanbul
#
# [99457 rows x 10 columns]>

# %% [markdown]
# ###แก้ค่า Age ของ invoice

# %%
shopping_data[(shopping_data['invoice_no']==['I280590'])| (shopping_data['invoice_no']=='I210628')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-0ff6c8bf9fe7> in <cell line: 1>()
# ----> 1 shopping_data[(shopping_data['invoice_no']==['I280590'])| (shopping_data['invoice_no']=='I210628')]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __eq__(self, other)
#      40     @unpack_zerodim_and_defer("__eq__")
#      41     def __eq__(self, other):
# ---> 42         return self._cmp_method(other, operator.eq)
#      43
#      44     @unpack_zerodim_and_defer("__ne__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    6241
#    6242         with np.errstate(all="ignore"):
# -> 6243             res_values = ops.comparison_op(lvalues, rvalues, op)
#    6244
#    6245         return self._construct_result(res_values, name=res_name)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     262         #  The ambiguous case is object-dtype.  See GH#27803
#     263         if len(lvalues) != len(rvalues):
# --> 264             raise ValueError(
#     265                 "Lengths must match to compare", lvalues.shape, rvalues.shape
#     266             )
#
# ValueError: ('Lengths must match to compare', (99457,), (1,))

# %%
shopping_data.loc[55784,'age']='less than 18'

# %%
shopping_data.iloc[55784,:]
# Out:
# invoice_no               I210628
# customer_id              C525437
# gender                    Female
# age                 less than 18
# category                   Books
# quantity                       2
# price                       30.3
# payment_method              Cash
# invoice_date          30/09/2022
# shopping_mall     Forum Istanbul
# Name: 55784, dtype: object

# %%
shopping_data.iloc[78728,:]
# Out:
# invoice_no               I280590
# customer_id              C142284
# gender                    Female
# age                           18
# category                Clothing
# quantity                       2
# price                     600.16
# payment_method        Debit Card
# invoice_date          26/10/2022
# shopping_mall     Forum Istanbul
# Name: 78728, dtype: object

# %% [markdown]
# ###สมมติว่าerror บอกว่าไม่สามารถประมวลผลค่า 'less than 18' ได้

# %% [markdown]
# ###หาว่าค่าที่ทำให้error อยู่ไหน

# %%
shopping_data[shopping_data.eq('less than 18').any(1)]
# Out:
# <ipython-input-16-4744250e9fad>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   shopping_data[shopping_data.eq('less than 18').any(1)]
#       invoice_no customer_id  gender           age category  quantity  price  \
# 55784    I210628     C525437  Female  less than 18    Books         2   30.3
#
#       payment_method invoice_date   shopping_mall
# 55784           Cash   30/09/2022  Forum Istanbul

# %%
shopping_data['age']shopping_data.eq('less than 18').any()]

# %% [markdown]
# ## Example

# %% [markdown]
# ## Fix

# %% [markdown]
# # ข้อมูลมีค่าตัวแปรไม่สอดคล้องซึ่งกันและกัน (Inconsistent)

# %% [markdown]
# ## Example
# เกิดเมื่อเรารวมข้อมูลจากหลายแหล่งแล้วมีค่า2คอมลัมน์  ไม่เป็นไปในทางเดียวกัน เช่นคอลัมน์อายุไม่ตรงกับคอลัมน์วันเกิดหลังจากคำนวณอายุแล้ว

# %% [markdown]
# ## Fix

# %%
เลือกเก็บไว้เฉพาะคอลัมน์ที่ถูก

# %% [markdown]
# ##DATA Integration(การรรวมข้อมูลจากหลายแหล่ง)

# %%
Octo_df = pd.read_excel('/content/drive/MyDrive/DataViz23Data/Oct65.xlsx', header=9,skipfooter=27)
sep_df =pd.read_excel('/content/drive/MyDrive/DataViz23Data/Sep65.xlsx',header=8,skipfooter=26)

# %%
sep_df=sep_df.iloc[-2:,:15] #เอาตั้งเเต่เเถว-2ด้านล่าง ถึงคอลัมน์0ถึง15
sep_df['เดือน-ปี'] = len(sep_df)*['sep-65']#เพิ่มคอลัมน์เดือนปี  โดยเอาจำนวนrowคูณด้วยข้อมูลที่ต้องการใส่(การลูปข้อมูลซ้ำๆ)
sep_df
# Out:
#   รายการ      งบประมาณ  สำรองเงินมีหนี้            PO      เบิกจ่าย  \
# 2  ประจำ  1.892013e+10     7.925745e+07  7.131600e+07  1.880196e+10
# 3  ลงทุน  9.605258e+09     2.683430e+08  1.119320e+09  8.201965e+09
#
#    ร้อยละ\nเบิกจ่าย  เป้า\nหมาย Q4  */- เป้าหมาย  การใช้จ่าย (PO+เบิกจ่าย)  \
# 2         99.375405           98.0      1.375405              1.895253e+10
# 3         85.390363           75.0     10.390363              9.589628e+09
#
#    ร้อยละ\nการใช้จ่าย  เป้า\nหมาย Q4.1  */- เป้าหมาย.1  \
# 2          100.171242            100.0        0.171242
# 3           99.837275            100.0       -0.162725
#
#    คงเหลือ\nหลังหักใช้จ่าย  ลำดับเบิกจ่าย  ลำดับ\nใช้จ่าย เดือน-ปี
# 2            -3.239918e+07            NaN             NaN   sep-65
# 3             1.563013e+07            6.0            15.0   sep-65

# %%
oct_df= Octo_df.iloc[-2:,:15]
oct_df['เดือน-ปี'] = len(oct_df)*['Octo-65']
oct_df
# Out:
#   รายการ     งบประมาณ  สำรองเงินมีหนี้          PO     เบิกจ่าย  \
# 2  ประจำ  6822.811789              NaN   12.706842  3984.779058
# 3  ลงทุน  6180.211723              NaN  457.295806  1291.209026
#
#    ร้อยละ\nเบิกจ่าย  เป้า\nหมาย Q1  */- เป้าหมาย  การใช้จ่าย (PO+เบิกจ่าย)  \
# 2         58.403766           35.0     23.403766               3997.485900
# 3         20.892634           19.0      1.892634               1748.504832
#
#    ร้อยละ\nการใช้จ่าย  เป้า\nหมาย Q1.1  */- เป้าหมาย.1  \
# 2           58.590007            35.33       23.260007
# 3           28.291989            28.96       -0.668011
#
#    คงเหลือ\nหลังหักใช้จ่าย  ลำดับเบิกจ่าย  ลำดับ\nใช้จ่าย เดือน-ปี
# 2              2825.325889            NaN             NaN  Octo-65
# 3              4431.706890            4.0             6.0  Octo-65

# %% [markdown]
# ##1.รวมแนวแกนx(เพิ่มคอลัมน์ เพิ่มfeature)

# %% [markdown]
# ##2.ต่อตารางy (เพิ่มแถว)

# %%
2.
